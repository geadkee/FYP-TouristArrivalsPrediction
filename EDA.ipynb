# %% [markdown]
# # EDA

# %%
import csv
import sys
import os
import pandas as pd
import numpy as np
from datetime import datetime

from matplotlib import pyplot as plt
# %matplotlib inline
from prophet import Prophet

# %%
print(sys.executable)
os.chdir(r"C:\Users\ggk\FYP-TouristArrivalsPrediction\dataset")

# %% [markdown]
# ## EDA of Malaysia

# %%
file1 = pd.read_excel(r"arr.xlsx")
file1.head()
file1["yeMon"] = pd.to_datetime(file1["Year"].map(str) + '-' + file1["Month"].map(str))
print(file1)
# Out:
#      Year  Month  Arrivals      yeMon
# 0    2000      1    731509 2000-01-01
# 1    2000      2    786040 2000-02-01
# 2    2000      3    737678 2000-03-01
# 3    2000      4    916382 2000-04-01
# 4    2000      5    894350 2000-05-01
# ..    ...    ...       ...        ...
# 271  2022      8   1102625 2022-08-01
# 272  2022      9   1245278 2022-09-01
# 273  2022     10   1344091 2022-10-01
# 274  2022     11   1330700 2022-11-01
# 275  2022     12   1839892 2022-12-01
#
# [276 rows x 4 columns]

# %%
# #Change column names into Prophet format
file1 = file1.rename(columns={'yeMon':'ds', 'Arrivals' :'y'})

# %%
file1.head(20)
# Out:
#     Year  Month        y         ds
# 0   2000      1   731509 2000-01-01
# 1   2000      2   786040 2000-02-01
# 2   2000      3   737678 2000-03-01
# 3   2000      4   916382 2000-04-01
# 4   2000      5   894350 2000-05-01
# 5   2000      6   960782 2000-06-01
# 6   2000      7   811876 2000-07-01
# 7   2000      8   764500 2000-08-01
# 8   2000      9   778587 2000-09-01
# 9   2000     10   990658 2000-10-01
# 10  2000     11   806648 2000-11-01
# 11  2000     12  1042572 2000-12-01
# 12  2001      1  1052854 2001-01-01
# 13  2001      2  1090219 2001-02-01
# 14  2001      3  1492235 2001-03-01
# 15  2001      4  1358776 2001-04-01
# 16  2001      5  1038210 2001-05-01
# 17  2001      6  1308788 2001-06-01
# 18  2001      7  1125504 2001-07-01
# 19  2001      8  1149987 2001-08-01

# %%
#Plot No.of Tourist Arrivals to Thailand
plt.figure(figsize=(15,6))
plt.plot(file1.set_index('ds'))
plt.title('Graph of Tourist Arrivals to Malaysia [2000 - 2022]')
# Out:
# Text(0.5, 1.0, 'Graph of Tourist Arrivals to Malaysia [2000 - 2022]')

# %% [markdown]
# ## EDA of Thailand

# %%
# load the dataset
file = pd.read_excel(r"TH-2010-2022.xlsx")
file.head()
file["yeMon"] = pd.to_datetime(file["Year"].map(str) + '-' + file["Month"].map(str))
# Out:
# c:\ProgramData\Anaconda3\envs\wordcloud\python.exe

# %%
file
# Out:
#      Year  Month        y         ds
# 0    2010      1  1605505 2010-01-01
# 1    2010      2  1614844 2010-02-01
# 2    2010      3  1439401 2010-03-01
# 3    2010      4  1108209 2010-04-01
# 4    2010      5   826610 2010-05-01
# ..    ...    ...      ...        ...
# 151  2022      8  1174743 2022-08-01
# 152  2022      9  1309115 2022-09-01
# 153  2022     10  1475430 2022-10-01
# 154  2022     11  1748366 2022-11-01
# 155  2022     12  2241195 2022-12-01
#
# [156 rows x 4 columns]

# %%
# #Change column names into Prophet format
file = file.rename(columns={'yeMon':'ds', 'Arrivals' :'y'})

# #Change to Pandas datetime format
# file['ds'] = pd.to_datetime(file['ds'])

file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    156 non-null    int64
#  1   Month   156 non-null    int64
#  2   y       156 non-null    int64
#  3   ds      156 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 5.0 KB

# %%
#Plot No.of Tourist Arrivals to Thailand
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)

ax.plot(file["ds"],file["y"])
for xy in zip(file["ds"],file["y"]):                                       # <--
    ax.annotate('(%s, %s)' % xy, xy=xy, textcoords='data') # <--

ax.grid()
plt.show()

# plt.plot(file.set_index('ds'))
# plt.title('Graph of Tourist Arrivals to Thailand [2010 - 2022]')

# %%
plt.figure(figsize=(15,6))
# plt.bar(file1["ds"], file1["y"], color='orange', width=10)
plt.plot(file1["ds"], file1["y"], color='green', lw=1)
plt.plot(file["ds"], file["y"], color='red', lw=1)
